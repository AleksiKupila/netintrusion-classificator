# %% [markdown]
# # Network Intrusion Classification – Dummy Test Pipeline
#
# Lightweight test pipeline using a **5000-row stratified sample** of the CICIDS2017 dataset.
#
# **Steps:**
# 1. Load data & stratified sampling
# 2. Pre-processing (scaling, label encoding)
# 3. Feature selection (SelectKBest – ANOVA F-score)
# 4. Dimensionality reduction (PCA)
# 5. Model training with GridSearchCV (rough param grids)
# 6. Evaluation & comparison

# %% [markdown]
# ## 1 · Imports & Setup

# %%
import warnings
warnings.filterwarnings('ignore')
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, ConfusionMatrixDisplay
)

RANDOM_STATE = 42
SAMPLE_SIZE  = 5_000

# %% [markdown]
# ## 2 · Load Data & Stratified Sampling

# %%
# Load dataset
try:
    df = pd.read_csv("data/cicids2017_cleaned.csv")
    print(f"Dataset loaded – shape: {df.shape}")
except Exception as e:
    raise RuntimeError(f"Loading failed: {e}")

X_full = df.iloc[:, :-1]
y_full = df.iloc[:, -1]

print("\nClass distribution (full dataset):")
print(y_full.value_counts())
# Out:
# Dataset loaded – shape: (2520751, 53)
#
# Class distribution (full dataset):
# Attack Type
# Normal Traffic    2095057
# DoS                193745
# DDoS               128014
# Port Scanning       90694
# Brute Force          9150
# Web Attacks          2143
# Bots                 1948
# Name: count, dtype: int64

# %%
# Stratified sample of 500 rows
sss = StratifiedShuffleSplit(n_splits=1, train_size=SAMPLE_SIZE, random_state=RANDOM_STATE)
sample_idx, _ = next(sss.split(X_full, y_full))

X_sample = X_full.iloc[sample_idx].reset_index(drop=True)
y_sample = y_full.iloc[sample_idx].reset_index(drop=True)

print(f"Sampled rows : {len(X_sample)}")
print(f"Feature count: {X_sample.shape[1]}")
print("\nClass distribution (sample):")
print(y_sample.value_counts())
# Out:
# Sampled rows : 50000
# Feature count: 52
#
# Class distribution (sample):
# Attack Type
# Normal Traffic    41556
# DoS                3843
# DDoS               2539
# Port Scanning      1799
# Brute Force         181
# Web Attacks          43
# Bots                 39
# Name: count, dtype: int64

# %% [markdown]
# ## 3 · Pre-processing

# %%
# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y_sample)
print("Classes:", list(le.classes_))

# Remove inf/NaN, drop zero-variance columns, impute medians
X_clean = X_sample.replace([np.inf, -np.inf], np.nan)
X_clean = X_clean.dropna(axis=1, how='all')
X_clean = X_clean.fillna(X_clean.median(numeric_only=True))
X_clean = X_clean.loc[:, X_clean.std() > 0]
print(f"Features after cleaning: {X_clean.shape[1]}")

# Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_clean.values, y_encoded,
    test_size=0.2, stratify=y_encoded, random_state=RANDOM_STATE
)
print(f"Train: {X_train.shape}  |  Test: {X_test.shape}")
# Out:
# Classes: ['Bots', 'Brute Force', 'DDoS', 'DoS', 'Normal Traffic', 'Port Scanning', 'Web Attacks']
# Features after cleaning: 52
# Train: (40000, 52)  |  Test: (10000, 52)

# %% [markdown]
# ## 4 · Feature Selection (SelectKBest, top 20)

# %%
K_FEATURES = 20

# Scale, then select top-K features by ANOVA F-score
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

selector = SelectKBest(score_func=f_classif, k=K_FEATURES)
X_train_fs = selector.fit_transform(X_train_scaled, y_train)
X_test_fs  = selector.transform(X_test_scaled)

selected_names = X_clean.columns[selector.get_support()].tolist()
print(f"Selected {K_FEATURES} features:")
for f in selected_names:
    print(f"  • {f}")

# Bar chart of feature scores
scores_df = pd.DataFrame({'feature': X_clean.columns, 'score': selector.scores_}) \
              .sort_values('score', ascending=False).head(K_FEATURES)

plt.figure(figsize=(10, 5))
sns.barplot(data=scores_df, x='score', y='feature', palette='viridis')
plt.title(f'Top {K_FEATURES} Features – ANOVA F-score')
plt.tight_layout()
plt.show()
# Out:
# Selected 20 features:
#   • Flow Duration
#   • Bwd Packet Length Max
#   • Bwd Packet Length Mean
#   • Bwd Packet Length Std
#   • Flow IAT Mean
#   • Flow IAT Std
#   • Flow IAT Max
#   • Fwd IAT Total
#   • Fwd IAT Std
#   • Fwd IAT Max
#   • Bwd IAT Std
#   • Max Packet Length
#   • Packet Length Mean
#   • Packet Length Std
#   • Packet Length Variance
#   • FIN Flag Count
#   • Average Packet Size
#   • Idle Mean
#   • Idle Max
#   • Idle Min

# %% [markdown]
# ## 5 · Dimensionality Reduction (PCA, 10 components)

# %%
N_COMPONENTS = 10

pca = PCA(n_components=N_COMPONENTS, random_state=RANDOM_STATE)
X_train_pca = pca.fit_transform(X_train_fs)
X_test_pca  = pca.transform(X_test_fs)

cumulative = np.cumsum(pca.explained_variance_ratio_)
print(f"Cumulative variance ({N_COMPONENTS} components): {cumulative[-1]*100:.1f}%")

# Scree plot
plt.figure(figsize=(8, 4))
plt.bar(range(1, N_COMPONENTS + 1), pca.explained_variance_ratio_ * 100,
        label='Individual', color='steelblue')
plt.plot(range(1, N_COMPONENTS + 1), cumulative * 100,
         marker='o', color='coral', label='Cumulative')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance (%)')
plt.title('PCA – Explained Variance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Cumulative variance (10 components): 99.4%

# %% [markdown]
# ## 6 · Model Training with GridSearchCV
#
# Each classifier is tuned with a **rough parameter grid** (5-fold CV) on the
# feature-selected input. The best estimator is then also scored on the PCA input.

# %%
# Rough parameter grids
search_configs = {
    'Logistic Regression': (
        LogisticRegression(max_iter=1000, random_state=RANDOM_STATE, solver='lbfgs'),
        {'C': [0.01, 0.1, 1, 10]}
    ),
    'k-NN': (
        KNeighborsClassifier(),
        {'n_neighbors': [3, 5, 11], 'weights': ['uniform', 'distance']}
    ),
    'Naive Bayes': (
        GaussianNB(),
        {'var_smoothing': [1e-9, 1e-7, 1e-5]}
    ),
}

# Run grid search and collect results
results = {}

for name, (estimator, param_grid) in search_configs.items():
    # Grid search on FS input
    gs = GridSearchCV(estimator, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    gs.fit(X_train_fs, y_train)
    best = gs.best_estimator_

    # Score on FS test set
    y_pred_fs = best.predict(X_test_fs)

    # Re-fit best params on PCA input, then score
    pca_model = copy.deepcopy(best)
    pca_model.fit(X_train_pca, y_train)
    y_pred_pca = pca_model.predict(X_test_pca)

    results[name] = {
        'best_params': gs.best_params_,
        'cv_score'   : gs.best_score_,
        'acc_fs'     : accuracy_score(y_test, y_pred_fs),
        'acc_pca'    : accuracy_score(y_test, y_pred_pca),
        'y_pred_fs'  : y_pred_fs,
        'report_fs'  : classification_report(y_test, y_pred_fs,
                           labels=np.unique(y_test),
                           target_names=le.inverse_transform(np.unique(y_test)),
                           zero_division=0),
        'report_pca' : classification_report(y_test, y_pred_pca,
                           labels=np.unique(y_test),
                           target_names=le.inverse_transform(np.unique(y_test)),
                           zero_division=0),
    }
    print(f"{name:22s}  best={gs.best_params_}  CV={gs.best_score_:.4f}")

print("\nGrid search complete.")
# Out:
# Logistic Regression     best={'C': 10}  CV=0.9154
# k-NN                    best={'n_neighbors': 3, 'weights': 'distance'}  CV=0.9908
# Naive Bayes             best={'var_smoothing': 1e-05}  CV=0.2496
#
# Grid search complete.

# %% [markdown]
# ## 7 · Evaluation & Comparison

# %%
# Summary table
rows = []
for name, r in results.items():
    rows.append({'Model': name, 'Best Params': r['best_params'],
                 'CV Acc': round(r['cv_score'], 4),
                 'Test Acc (FS)': round(r['acc_fs'], 4),
                 'Test Acc (PCA)': round(r['acc_pca'], 4)})

summary = pd.DataFrame(rows)
print("=" * 75)
print("MODEL COMPARISON SUMMARY")
print("=" * 75)
print(summary.to_string(index=False))
print("=" * 75)
# Out:
# ===========================================================================
# MODEL COMPARISON SUMMARY
# ===========================================================================
#               Model                               Best Params  CV Acc  Test Acc (FS)  Test Acc (PCA)
# Logistic Regression                                 {'C': 10}  0.9154         0.9158          0.9094
#                k-NN {'n_neighbors': 3, 'weights': 'distance'}  0.9908         0.9917          0.9913
#         Naive Bayes                  {'var_smoothing': 1e-05}  0.2496         0.2456          0.3150
# ===========================================================================

# %%
# Bar chart – FS vs PCA test accuracy per classifier
labels  = list(results.keys())
acc_fs  = [results[n]['acc_fs']  for n in labels]
acc_pca = [results[n]['acc_pca'] for n in labels]
x, width = np.arange(len(labels)), 0.35

fig, ax = plt.subplots(figsize=(9, 5))
bars1 = ax.bar(x - width/2, acc_fs,  width, label='FS (20 features)',   color='steelblue')
bars2 = ax.bar(x + width/2, acc_pca, width, label='PCA (10 components)', color='coral')

for bar in bars1 + bars2:
    ax.annotate(f'{bar.get_height():.2f}',
                xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                xytext=(0, 3), textcoords='offset points', ha='center', fontsize=9)

ax.set_xlabel('Classifier')
ax.set_ylabel('Test Accuracy')
ax.set_title('Classifier Comparison – FS vs PCA Input')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(0, 1.1)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Confusion matrices (FS input)
'''
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
fig.suptitle('Confusion Matrices – Feature-Selected Input', fontsize=13)

for ax, name in zip(axes, results):
    cm = confusion_matrix(y_test, results[name]['y_pred_fs'])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.inverse_transform(np.unique(y_test)))
    ax.set_title(name)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=7)
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=7)

plt.tight_layout()
plt.show()
'''
# Out:
# "\nfig, axes = plt.subplots(1, 3, figsize=(16, 4))\nfig.suptitle('Confusion Matrices – Feature-Selected Input', fontsize=13)\n\nfor ax, name in zip(axes, results):\n    cm = confusion_matrix(y_test, results[name]['y_pred_fs'])\n    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)\n    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.inverse_transform(np.unique(y_test)))\n    ax.set_title(name)\n    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=7)\n    ax.set_yticklabels(ax.get_yticklabels(), fontsize=7)\n\nplt.tight_layout()\nplt.show()\n"

# %%
# Per-class classification reports
for name, r in results.items():
    print(f"\n{'='*60}")
    print(f"  {name}  –  FS input  (best params: {r['best_params']})")
    print('='*60)
    print(r['report_fs'])

    print(f"\n{'='*60}")
    print(f"  {name}  –  PCA input")
    print('='*60)
    print(r['report_pca'])
# Out:
# ============================================================
#   Logistic Regression  –  FS input  (best params: {'C': 10})
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.00      0.00      0.00         8
#    Brute Force       0.85      0.31      0.45        36
#           DDoS       0.82      0.54      0.65       508
#            DoS       0.91      0.78      0.84       768
# Normal Traffic       0.92      1.00      0.96      8311
#  Port Scanning       0.00      0.00      0.00       360
#    Web Attacks       0.00      0.00      0.00         9
#
#       accuracy                           0.92     10000
#      macro avg       0.50      0.37      0.41     10000
#   weighted avg       0.88      0.92      0.89     10000
#
#
# ============================================================
#   Logistic Regression  –  PCA input
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.00      0.00      0.00         8
#    Brute Force       0.00      0.00      0.00        36
#           DDoS       0.75      0.49      0.59       508
#            DoS       0.92      0.73      0.82       768
# Normal Traffic       0.91      1.00      0.95      8311
#  Port Scanning       0.00      0.00      0.00       360
#    Web Attacks       0.00      0.00      0.00         9
#
#       accuracy                           0.91     10000
#      macro avg       0.37      0.32      0.34     10000
#   weighted avg       0.87      0.91      0.89     10000
#
#
# ============================================================
#   k-NN  –  FS input  (best params: {'n_neighbors': 3, 'weights': 'distance'})
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.67      0.50      0.57         8
#    Brute Force       1.00      0.94      0.97        36
#           DDoS       0.97      0.98      0.97       508
#            DoS       0.96      0.96      0.96       768
# Normal Traffic       1.00      1.00      1.00      8311
#  Port Scanning       1.00      0.99      1.00       360
#    Web Attacks       1.00      0.22      0.36         9
#
#       accuracy                           0.99     10000
#      macro avg       0.94      0.80      0.83     10000
#   weighted avg       0.99      0.99      0.99     10000
#
#
# ============================================================
#   k-NN  –  PCA input
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.67      0.50      0.57         8
#    Brute Force       1.00      0.94      0.97        36
#           DDoS       0.96      0.97      0.97       508
#            DoS       0.96      0.96      0.96       768
# Normal Traffic       1.00      1.00      1.00      8311
#  Port Scanning       0.99      0.99      0.99       360
#    Web Attacks       1.00      0.22      0.36         9
#
#       accuracy                           0.99     10000
#      macro avg       0.94      0.80      0.83     10000
#   weighted avg       0.99      0.99      0.99     10000
#
#
# ============================================================
#   Naive Bayes  –  FS input  (best params: {'var_smoothing': 1e-05})
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.00      1.00      0.00         8
#    Brute Force       0.13      0.75      0.23        36
#           DDoS       0.44      0.48      0.46       508
#            DoS       0.53      0.79      0.64       768
# Normal Traffic       0.90      0.19      0.31      8311
#  Port Scanning       0.00      0.00      0.00       360
#    Web Attacks       0.02      0.78      0.04         9
#
#       accuracy                           0.25     10000
#      macro avg       0.29      0.57      0.24     10000
#   weighted avg       0.81      0.25      0.33     10000
#
#
# ============================================================
#   Naive Bayes  –  PCA input
# ============================================================
#                 precision    recall  f1-score   support
#
#           Bots       0.00      1.00      0.00         8
#    Brute Force       0.39      0.75      0.51        36
#           DDoS       0.54      0.52      0.53       508
#            DoS       0.55      0.79      0.65       768
# Normal Traffic       0.97      0.27      0.42      8311
#  Port Scanning       0.00      0.00      0.00       360
#    Web Attacks       0.02      0.78      0.04         9
#
#       accuracy                           0.32     10000
#      macro avg       0.35      0.59      0.31     10000
#   weighted avg       0.88      0.32      0.43     10000
