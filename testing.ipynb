# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

# Load the data
try:
    df = pd.read_csv("data/cicids2017_cleaned.csv")
    print("Loading data successful!")
except Exception as e:
    raise RuntimeError(f"Loading data failed: {e}")

# Features and target
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Stratified sampling
samples = StratifiedShuffleSplit(n_splits=1, train_size=500, random_state=42)
sample_idx, _ = next(samples.split(X, y))

X_sample = X.iloc[sample_idx].reset_index(drop=True)
y_sample = y.iloc[sample_idx].reset_index(drop=True)

# Split sampled data into train/test (80/20)
X_train, X_test, y_train, y_test = train_test_split(
    X_sample,
    y_sample,
    test_size=0.2,
    stratify=y_sample,
    random_state=42
)

print(f"Sampled rows: {len(X_sample)}")
print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# Loading data successful!
# Sampled rows: 500
# Train shape: (400, 52), Test shape: (100, 52)
